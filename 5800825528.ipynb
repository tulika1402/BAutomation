# %% [markdown]
# <a href="https://colab.research.google.com/github/tulika1402/BAutomation/blob/main/5800825528.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr
# Out:
# Collecting easyocr
#   Downloading easyocr-1.7.1-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from easyocr) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.17.1+cu121)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from easyocr) (4.9.0.80)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.11.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from easyocr) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from easyocr) (9.4.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from easyocr) (0.19.3)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from easyocr) (2.0.3)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.3.0.post5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 17.0 MB/s eta 0:00:00
# Collecting ninja (from easyocr)
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->easyocr)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 29.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->easyocr)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 41.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->easyocr)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 51.5 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->easyocr)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->easyocr)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.4 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->easyocr)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->easyocr)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->easyocr)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.2 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->easyocr)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.4 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->easyocr)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.7 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->easyocr)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->easyocr) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->easyocr)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (2024.2.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->easyocr) (24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->easyocr) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->easyocr) (1.3.0)
# Installing collected packages: pyclipper, ninja, python-bidi, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, easyocr
# Successfully installed easyocr-1.7.1 ninja-1.11.1.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 pyclipper-1.3.0.post5 python-bidi-0.4.2

# %%
import easyocr

# %%
reader=easyocr.Reader(['en'],gpu= True)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import PIL
from PIL import ImageDraw

# %%
im=PIL.Image.open("/content/5800825528.jpg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2480x3505>

# %%
bounds=reader.readtext("/content/5800825528.jpg")

# %%
bounds
# Out:
# [([[186, 186], [770, 186], [770, 240], [186, 240]],
#   'Integrated Facility Management W.LL',
#   0.8112853944370133),
#  ([[215, 239], [1063, 239], [1063, 288], [215, 288]],
#   'CR:76416-1 RO. Box: 32571, Manama, Kingdom of Bahrain',
#   0.45743650275195163),
#  ([[215, 266], [443, 266], [443, 306], [215, 306]],
#   'FlatiShop No. 2_',
#   0.5063771445437737),
#  ([[451, 273], [905, 273], [905, 315], [451, 315]],
#   'Building: 230,Road/street 328,',
#   0.7774023130089996),
#  ([[214, 299], [314, 299], [314, 354], [214, 354]],
#   'Teirg',
#   0.15424926034842845),
#  ([[304, 295], [894, 295], [894, 343], [304, 343]],
#   'Salihiva Block 356, Capital Governorate;',
#   0.6368477302175142),
#  ([[1890, 261], [2277, 261], [2277, 401], [1890, 401]],
#   'IELJ',
#   0.12214226290424807),
#  ([[272, 333], [296, 333], [296, 351], [272, 351]], '+', 0.7180553600847048),
#  ([[290, 326], [349, 326], [349, 355], [290, 355]], '973', 0.9961065053939819),
#  ([[368, 325], [504, 325], [504, 361], [368, 361]],
#   '7402242_',
#   0.8337304613320407),
#  ([[512, 332], [653, 332], [653, 360], [512, 360]],
#   'Fax:+973',
#   0.9869581656982968),
#  ([[673, 331], [802, 331], [802, 364], [673, 364]],
#   '7404467',
#   0.8001578160515314),
#  ([[214, 351], [371, 351], [371, 382], [214, 382]],
#   'Email: info',
#   0.6059840041405249),
#  ([[364, 351], [648, 351], [648, 401], [364, 401]],
#   'ifm@almqayyedcg',
#   0.6963799466667034),
#  ([[642, 368], [712, 368], [712, 387], [642, 387]],
#   '-com',
#   0.22821955382823944),
#  ([[1903, 378], [2267, 378], [2267, 411], [1903, 411]],
#   'ERCLTAYING FUNCTIONALiTY',
#   0.05783786723658337),
#  ([[1900, 396], [2267, 396], [2267, 432], [1900, 432]],
#   'intagrated Facility Management',
#   0.7438302806376749),
#  ([[1036, 542], [1514, 542], [1514, 629], [1036, 629]],
#   'TAX INVOICE',
#   0.9088859968221795),
#  ([[235, 708], [298, 708], [298, 745], [235, 745]], 'Tax', 0.6222509145736694),
#  ([[401, 710], [499, 710], [499, 751], [401, 751]],
#   'Name',
#   0.9999462366104126),
#  ([[595, 714], [1143, 714], [1143, 766], [595, 766]],
#   'Almoayyed Contracting Group WLL',
#   0.7896015228490596),
#  ([[234, 751], [540, 751], [540, 799], [234, 799]],
#   'VAT Group Number',
#   0.820765304734246),
#  ([[592, 757], [872, 757], [872, 806], [592, 806]],
#   '210000308300002',
#   0.9999836250707418),
#  ([[232, 791], [536, 791], [536, 834], [232, 834]],
#   'Tax Group Address',
#   0.7269976871020062),
#  ([[593, 799], [660, 799], [660, 835], [593, 835]], 'Flat', 0.999830961227417),
#  ([[711, 795], [849, 795], [849, 846], [711, 846]],
#   'Building',
#   0.9999874823535403),
#  ([[919, 802], [1107, 802], [1107, 845], [919, 845]],
#   'Road/Street',
#   0.7682479119776947),
#  ([[1158, 808], [1585, 808], [1585, 857], [1158, 857]],
#   'Tashan, Block 407 , Bahrain',
#   0.6429185092669221),
#  ([[232, 865], [427, 865], [427, 901], [232, 901]],
#   'Invoice Date',
#   0.5942796890472872),
#  ([[572, 870], [745, 870], [745, 906], [572, 906]],
#   ':17-JAN-24',
#   0.7995606010330134),
#  ([[1341, 886], [1591, 886], [1591, 925], [1341, 925]],
#   'Invoice Number',
#   0.991035663911866),
#  ([[1683, 890], [1882, 890], [1882, 933], [1683, 933]],
#   ':5808025528',
#   0.7412617226535866),
#  ([[229, 914], [491, 914], [491, 964], [229, 964]],
#   'Customer Name',
#   0.7200844619778016),
#  ([[581, 923], [1258, 923], [1258, 979], [581, 979]],
#   'Yousuf Khalil Almoayyed & Sons Properties',
#   0.6753184629977818),
#  ([[1341, 941], [1520, 941], [1520, 980], [1341, 980]],
#   'Cust: Code',
#   0.9545040129495816),
#  ([[1694, 947], [1815, 947], [1815, 986], [1694, 986]],
#   'YOO04C',
#   0.34944918640663697),
#  ([[572, 963], [731, 963], [731, 1002], [572, 1002]],
#   'Co.WLL',
#   0.9926947707715374),
#  ([[229, 992], [365, 992], [365, 1033], [229, 1033]],
#   'Address',
#   0.9999973867000719),
#  ([[567, 996], [767, 996], [767, 1045], [567, 1045]],
#   ':FlatShop:11',
#   0.7702078639915276),
#  ([[766, 997], [893, 997], [893, 1051], [766, 1051]],
#   'Building',
#   0.6659444393680293),
#  ([[911, 1007], [1114, 1007], [1114, 1046], [911, 1046]],
#   '3 Road/Street',
#   0.9642899591568964),
#  ([[1131, 1013], [1190, 1013], [1190, 1045], [1131, 1045]], '401', 1.0),
#  ([[1341, 1015], [1624, 1015], [1624, 1059], [1341, 1059]],
#   'Cust VAT Number',
#   0.8243796350567906),
#  ([[1681, 1022], [1969, 1022], [1969, 1066], [1681, 1066]],
#   ':200011241300002',
#   0.8987053263729065),
#  ([[579, 1039], [996, 1039], [996, 1082], [579, 1082]],
#   'Town: Manama Centre,Block',
#   0.9806029170275677),
#  ([[1058, 1047], [1170, 1047], [1170, 1089], [1058, 1089]],
#   'Capital',
#   0.7449047431922955),
#  ([[1340, 1053], [1479, 1053], [1479, 1093], [1340, 1093]],
#   'Voucher',
#   0.9997703730483855),
#  ([[566, 1075], [871, 1075], [871, 1115], [566, 1115]],
#   'Governorate,Bahrain',
#   0.9854456402811476),
#  ([[1677, 1059], [1881, 1059], [1881, 1104], [1677, 1104]],
#   ':5824300079',
#   0.9896680002895706),
#  ([[227, 1106], [287, 1106], [287, 1142], [227, 1142]],
#   'Ref',
#   0.9999975911073493),
#  ([[566, 1113], [879, 1113], [879, 1155], [566, 1155]],
#   ':MATERIAL SUPPLY',
#   0.9767404714931743),
#  ([[1338, 1127], [1402, 1127], [1402, 1164], [1338, 1164]],
#   'Job',
#   0.999989400878152),
#  ([[1678, 1136], [1843, 1136], [1843, 1177], [1678, 1177]],
#   ':IFCP0352',
#   0.686687344613296),
#  ([[226, 1159], [477, 1159], [477, 1212], [226, 1212]],
#   'Cust. VAT Regn',
#   0.6512374342093724),
#  ([[583, 1167], [1263, 1167], [1263, 1219], [583, 1219]],
#   'Yousuf Khalil Almoayyed & Sons Properties Co_',
#   0.9949331806419064),
#  ([[227, 1201], [317, 1201], [317, 1237], [227, 1237]],
#   'Name',
#   0.9999523758888245),
#  ([[566, 1207], [660, 1207], [660, 1243], [566, 1243]],
#   'WLL',
#   0.9990163417481358),
#  ([[448, 1357], [621, 1357], [621, 1394], [448, 1394]],
#   'Particulars',
#   0.9999924879042108),
#  ([[1029, 1366], [1189, 1366], [1189, 1408], [1029, 1408]],
#   'Unit Price',
#   0.9967209782716425),
#  ([[1341, 1355], [1443, 1355], [1443, 1391], [1341, 1391]],
#   'Gross',
#   0.999991630009511),
#  ([[1571, 1360], [1629, 1360], [1629, 1396], [1571, 1396]],
#   'Vat',
#   0.8266556859016418),
#  ([[1989, 1367], [2077, 1367], [2077, 1409], [1989, 1409]],
#   'Total',
#   0.9988918119600776),
#  ([[1286, 1390], [1506, 1390], [1506, 1434], [1286, 1434]],
#   'Amount(BHD)',
#   0.9998058956511083),
#  ([[1586, 1400], [1620, 1400], [1620, 1431], [1586, 1431]],
#   '%',
#   0.9380024450951083),
#  ([[1691, 1382], [1829, 1382], [1829, 1424], [1691, 1424]],
#   'Vat BHD',
#   0.9222856098492955),
#  ([[1927, 1406], [2147, 1406], [2147, 1449], [1927, 1449]],
#   'Amount(BHD)',
#   0.9863653043716418),
#  ([[227, 1459], [668, 1459], [668, 1503], [227, 1503]],
#   'CIVIL MAINTENANCE WORK',
#   0.9985985094740439),
#  ([[226, 1507], [579, 1507], [579, 1556], [226, 1556]],
#   'FOR YKAP BUILDINGS',
#   0.9987763102588194),
#  ([[1097, 1527], [1224, 1527], [1224, 1563], [1097, 1563]],
#   '143.430',
#   0.6289353320736724),
#  ([[1404, 1533], [1530, 1533], [1530, 1574], [1404, 1574]],
#   '143.430',
#   0.9332274525738241),
#  ([[1597, 1539], [1636, 1539], [1636, 1571], [1597, 1571]],
#   '10',
#   0.9999812868505445),
#  ([[1763, 1541], [1870, 1541], [1870, 1580], [1763, 1580]],
#   '14.343',
#   0.7638566700274679),
#  ([[2037, 1546], [2160, 1546], [2160, 1585], [2037, 1585]],
#   '157.773',
#   0.9873551493811674),
#  ([[1552, 1735], [1865, 1735], [1865, 1780], [1552, 1780]],
#   'Total excl:  VAT BHD',
#   0.381437466734646),
#  ([[2028, 1745], [2153, 1745], [2153, 1786], [2028, 1786]],
#   '143.430',
#   0.48093334134609034),
#  ([[1713, 1790], [1862, 1790], [1862, 1829], [1713, 1829]],
#   'VAT BHD',
#   0.9955375441582404),
#  ([[2045, 1798], [2149, 1798], [2149, 1834], [2045, 1834]],
#   '14.343',
#   0.8418105841956769),
#  ([[1691, 1828], [1774, 1828], [1774, 1865], [1691, 1865]],
#   'Total',
#   0.9998851651414105),
#  ([[1785, 1831], [1862, 1831], [1862, 1867], [1785, 1867]],
#   'BHD',
#   0.9999862349096102),
#  ([[2025, 1836], [2150, 1836], [2150, 1876], [2025, 1876]],
#   '157.773',
#   0.9999257904356665),
#  ([[1578, 1877], [1773, 1877], [1773, 1920], [1578, 1920]],
#   'Balance due',
#   0.9737422128479641),
#  ([[1785, 1883], [1859, 1883], [1859, 1919], [1785, 1919]],
#   'BKD',
#   0.6373174009776639),
#  ([[2026, 1889], [2149, 1889], [2149, 1925], [2026, 1925]],
#   '157.773',
#   0.8082744549968296),
#  ([[148, 1991], [1412, 1991], [1412, 2058], [148, 2058]],
#   'Bahraini Dinars One Hundred Fifty-Seven And Fils Seven Hundred Seventy-Three Only',
#   0.7002249637073477),
#  ([[183, 2075], [506, 2075], [506, 2116], [183, 2116]],
#   'Qur Bank Alc Details',
#   0.6921479613025838),
#  ([[204, 2154], [386, 2154], [386, 2202], [204, 2202]],
#   'Bank Name',
#   0.6731343343140885),
#  ([[495, 2162], [858, 2162], [858, 2206], [495, 2206]],
#   'National Bank Of Bahrain',
#   0.7759104003159785),
#  ([[202, 2195], [348, 2195], [348, 2234], [202, 2234]],
#   'IBAN No.',
#   0.9165698346760829),
#  ([[494, 2197], [959, 2197], [959, 2246], [494, 2246]],
#   'BH32 NBOB 0000 0099 602768',
#   0.8772157729701839),
#  ([[1266, 2178], [1448, 2178], [1448, 2216], [1266, 2216]],
#   'Bank Name',
#   0.9069515841451589),
#  ([[1527, 2184], [1770, 2184], [1770, 2224], [1527, 2224]],
#   'Ahli United Bank',
#   0.9063837723414537),
#  ([[202, 2231], [320, 2231], [320, 2270], [202, 2270]],
#   'Ac No.',
#   0.805215307354253),
#  ([[492, 2235], [690, 2235], [690, 2277], [492, 2277]],
#   '0099-602768',
#   0.9117539971189305),
#  ([[1264, 2215], [1413, 2215], [1413, 2253], [1264, 2253]],
#   'IBAN No.',
#   0.9936601262642297),
#  ([[1523, 2217], [1948, 2217], [1948, 2269], [1523, 2269]],
#   'BH3GAUBBO0001238514001',
#   0.35259184063289317),
#  ([[1263, 2251], [1383, 2251], [1383, 2292], [1263, 2292]],
#   'Alc No.',
#   0.7182348135532435),
#  ([[1524, 2256], [1780, 2256], [1780, 2298], [1524, 2298]],
#   '0001-238514-001',
#   0.9892276111046855),
#  ([[143, 2304], [220, 2304], [220, 2345], [143, 2345]],
#   'Note',
#   0.9999845027923584),
#  ([[234, 2307], [854, 2307], [854, 2364], [234, 2364]],
#   'E* for Exempt Supply, O* for Out of Scope',
#   0.8444374329373722),
#  ([[377, 2546], [749, 2546], [749, 2611], [377, 2611]],
#   'WLi I &ilzaJl ajll',
#   0.0473194075670371),
#  ([[734, 2528], [965, 2528], [965, 2652], [734, 2652]],
#   'iFM',
#   0.9352679990553525),
#  ([[198, 2597], [748, 2597], [748, 2653], [198, 2653]],
#   'Integrated Facility Manogement',
#   0.6408040036756151),
#  ([[198, 2656], [967, 2656], [967, 2708], [198, 2708]],
#   'Integrated Facllity Managemant WALL C.R. 78416-1',
#   0.4259742263603326),
#  ([[199, 2702], [432, 2702], [432, 2744], [199, 2744]],
#   'PO. Box 32571',
#   0.5491285214709579),
#  ([[447, 2700], [965, 2700], [965, 2754], [447, 2754]],
#   'Tel : 17402242 - Kingdom of Bahrain',
#   0.455678227068899),
#  ([[684, 3200], [1739, 3200], [1739, 3272], [684, 3272]],
#   'This document is system generated and doesnt require signature.',
#   0.8482974154862066),
#  ([[2126, 3312], [2218, 3312], [2218, 3362], [2126, 3362]],
#   'Page',
#   0.9999180436134338),
#  ([[2235, 3319], [2296, 3319], [2296, 3350], [2235, 3350]],
#   '1 /1',
#   0.9977690577507019),
#  ([[301.052175279236, 705.1139186448675],
#    [404.9100841763293, 718.1566485109878],
#    [398.947824720764, 753.8860813551325],
#    [295.0899158236707, 741.8433514890122]],
#   'Group',
#   0.9999459947566783),
#  ([[661.9294245448556, 796.1459283614803],
#    [714.5636245876079, 803.1832502102391],
#    [710.0705754551444, 839.8540716385197],
#    [656.4363754123921, 832.8167497897609]],
#   '11,',
#   0.9998827222431269),
#  ([[851.0521752792359, 797.1139186448675],
#    [921.7669676463794, 807.6546544120074],
#    [914.9478247207641, 845.8860813551325],
#    [844.2330323536206, 835.3453455879926]],
#   '496,',
#   0.9998947381973267),
#  ([[1106.0064985989293, 804.1253445358238],
#    [1162.65255152975, 813.3693966385044],
#    [1155.9935014010707, 850.8746554641762],
#    [1099.34744847025, 841.6306033614956]],
#   '84,',
#   0.9999374378686863),
#  ([[999.0298574998546, 1041.1194299994186],
#    [1071.7622155987667, 1050.6414221448897],
#    [1065.9701425001454, 1088.8805700005814],
#    [992.2377844012332, 1079.3585778551103]],
#   '304,4',
#   0.17848939535716543),
#  ([[891.8918944820551, 1358.1243357210426],
#    [957.592063079055, 1369.0218805197917],
#    [949.1081055179449, 1411.8756642789574],
#    [883.407936920945, 1400.9781194802083]],
#   'aty',
#   0.7023489999741164)]

# %%
def draw_boxes(image,bounds,color="red",width=4):
  draw=ImageDraw.Draw(image)
  for bound in bounds:
    p0,p1,p2,p3=bound[0]
    draw.line([*p0,*p1,*p2,*p3,*p0], fill=color, width=width)
  return image

# %%
draw_boxes(im,bounds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2480x3505>

# %%
import pandas as pd

# %%
df=pd.DataFrame(bounds,columns=["bounding_box", "value","confidence_score"])

# %%
df
# Out:
#                                           bounding_box  \
# 0     [[186, 186], [770, 186], [770, 240], [186, 240]]
# 1    [[215, 239], [1063, 239], [1063, 288], [215, 2...
# 2     [[215, 266], [443, 266], [443, 306], [215, 306]]
# 3     [[451, 273], [905, 273], [905, 315], [451, 315]]
# 4     [[214, 299], [314, 299], [314, 354], [214, 354]]
# ..                                                 ...
# 109  [[661.9294245448556, 796.1459283614803], [714....
# 110  [[851.0521752792359, 797.1139186448675], [921....
# 111  [[1106.0064985989293, 804.1253445358238], [116...
# 112  [[999.0298574998546, 1041.1194299994186], [107...
# 113  [[891.8918944820551, 1358.1243357210426], [957...
#
#                                                  value  confidence_score
# 0                  Integrated Facility Management W.LL          0.811285
# 1    CR:76416-1 RO. Box: 32571, Manama, Kingdom of ...          0.457437
# 2                                     FlatiShop No. 2_          0.506377
# 3                       Building: 230,Road/street 328,          0.777402
# 4                                                Teirg          0.154249
# ..                                                 ...               ...
# 109                                                11,          0.999883
# 110                                               496,          0.999895
# 111                                                84,          0.999937
# 112                                              304,4          0.178489
# 113                                                aty          0.702349
#
# [114 rows x 3 columns]

# %%
 filtered_df = df[df['value'] == 'Invoice Number']

if not filtered_df.empty:
    index_any = filtered_df.index[0]
    following_value = df.loc[index_any + 1, 'value']
    print("INVOICE NO:", following_value)
else:
    print("No rows  found.")
# Out:
# INVOICE NO: :5808025528

# %%
filtered_df1 = df[df['value'] == 'Invoice Date']

if not filtered_df1.empty:
    index_any = filtered_df1.index[0]
    following_values1= df.loc[index_any + 1, 'value']
    print("Date-", following_values1)
else:
    print("No rows  found.")
# Out:
# Date- :17-JAN-24

# %%
  filtered_df2 = df[df['value'] == 'VAT Group Number']

  if not filtered_df2.empty:
    index_any = filtered_df2.index[0]
    following_value2 = df.loc[index_any + 1, 'value']
    print("VAT : ", following_value2)
  else:
    print("No rows  found.")
# Out:
# VAT :  210000308300002

# %%
  filtered_df3 = df[df['value'] == 'Customer Name']

  if not filtered_df3.empty:
    index_any = filtered_df3.index[0]
    following_value3 = df.loc[index_any +1, 'value']
    print("Name-", following_value3)
  else:
    print("No rows  found.")
# Out:
# Name- Yousuf Khalil Almoayyed & Sons Properties

# %%
  filtered_df4 = df[df['value'] == 'Vat']

  if not filtered_df4.empty:
    index_any = filtered_df4.index[0]
    following_value4 = df.loc[index_any + 16, 'value']
    print("VAT%", following_value4)
  else:
    print("No rows  found.F")
# Out:
# VAT% 14.343

# %%
  filtered_df5 = df[df['value'] == 'Total']

  if not filtered_df5.empty:
    index_any = filtered_df5.index[0]
    following_value5 = df.loc[index_any +11, 'value']
    print("Total Amount", following_value5)
  else:
    print("No rows  found.")
# Out:
# Total Amount 157.773

# %%
filtered_df6 = df[df['value'] == 'Particulars']

if not filtered_df6.empty:
    index_any = filtered_df6.index[0]

    index_any = int(index_any)

    following_value6 = (df.loc[index_any + 9, 'value'] + " " +
                        df.loc[index_any + 10, 'value'] + " " )



    print("PRODUCT- ", following_value6)  # Access values of the resulting DataFrame
else:
    print("No rows found.")
# Out:
# PRODUCT-  CIVIL MAINTENANCE WORK FOR YKAP BUILDINGS

# %%
import pandas as pd

data = {
    'Invoice Number': [following_value],
    'Invoice Date': [following_values1],
    'VAT Group Number': [following_value2],
    'Customer Name': [following_value3],
    'VAT': [following_value4],
    'Amount': [following_value5],
    'Particulars': [following_value6]
}

# Convert the dictionary into a DataFrame
df = pd.DataFrame(data)

# Fill NaN values in the DataFrame with the values in the first row
df = df.fillna(method='ffill')

# Print the DataFrame
print(df)
# Out:
#   Invoice Number Invoice Date VAT Group Number  \
# 0    :5808025528   :17-JAN-24  210000308300002
#
#                                Customer Name     VAT   Amount  \
# 0  Yousuf Khalil Almoayyed & Sons Properties  14.343  157.773
#
#                                   Particulars
# 0  CIVIL MAINTENANCE WORK FOR YKAP BUILDINGS
